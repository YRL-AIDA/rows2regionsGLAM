# %%
import pandas as pd

# %%
df = pd.read_csv('result/results.csv')

# %%
df
# Out:
#    Unnamed: 0  threshold_0.5 (1)  threshold_0.95 (1)  threshold_0.5 (2)  \
# 0           0           0.621071            0.589679           0.629973
# 1           1           0.546287            0.507636           0.665620
# 2           2           0.707171            0.683720           0.665828
# 3           3           0.729264            0.699486           0.688042
#
#    threshold_0.95 (2)  threshold_0.5 (3)  threshold_0.95 (3)  \
# 0            0.620147           0.440435            0.391068
# 1            0.662525           0.376495            0.339073
# 2            0.664578           0.501555            0.455012
# 3            0.680288           0.530776            0.488382
#
#    threshold_0.5 (4)  threshold_0.95 (4)  threshold_0.5 (5)  ...  \
# 0           0.714833            0.701500           0.501274  ...
# 1           0.760667            0.727000           0.566917  ...
# 2           0.752667            0.744333           0.574444  ...
# ...

# %%
# Out:
#       threshold_0.5 (all)  threshold_0.95 (all)  mAP (all)  mAP (seg)
# mean             0.770299              0.700966   0.249565   0.547529
# std              0.013148              0.017638   0.038340   0.020052
# min              0.754930              0.676862   0.178721   0.523238
# max              0.801011              0.741010   0.299258   0.587129
